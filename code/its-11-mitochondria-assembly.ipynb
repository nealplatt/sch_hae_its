# %%
import os
# import vcf
from pathlib import Path
from matplotlib import pyplot as plt
from matplotlib import cm
import pandas as pd
import yaml
import glob
import seaborn as sns
from Bio import SeqIO

# %% [markdown]
# # Mitochondria assembly

# %%
proj_dir="/master/nplatt/sch_hae_its-nigeria"
results_dir=f"{proj_dir}/results"

# %%
Path(f"{results_dir}/mito_assembly").mkdir(parents=True, exist_ok=True)
os.chdir(f"{results_dir}/mito_assembly")

# %%
info_df=pd.read_csv(f"{proj_dir}/its-nigeria_samplesheet.csv", sep=",")
info_df
# Out:
#               wgs_id                    its_id          sra       species  \
# 0       Sb_NG_ak_1.1             Sb.ng.ak.1.1F          NaN        sbovis
# 1       Sb_NG_ak_2.1              sb_ng_ak_2.1          NaN        sbovis
# 2       Sb_NG_ak_2.2             Sb.ng.ak.2.2F          NaN        sbovis
# 3       Sb_NG_ak_2.3             Sb.ng.ak.2.3F          NaN        sbovis
# 4       Sb_NG_ak_3.1             Sb.ng.ak.3.1R          NaN        sbovis
# ..               ...                       ...          ...           ...
# 200     Sh_NG_os_3_1              sh_ng_os_3_1          NaN  shaematobium
# 201  c_Sh_NG_os_3_11            Sh.ng.os.3.11F          NaN  shaematobium
# 202   c_Sh_NG_os_3_5             Sh.ng.os.3.5F          NaN  shaematobium
# 203   c_Sh_NG_os_3_6             Sh.ng.os.3.6F          NaN  shaematobium
# 204      SRR11907410  se_sha_pemba_uwandani_13  SRR11907410  shaematobium
#
#       country    locale patient miracidum
# 0     nigeria        ak       1         1
# 1     nigeria        ak       2         1
# 2     nigeria        ak       2         2
# 3     nigeria        ak       2         3
# 4     nigeria        ak       3         1
# ..        ...       ...     ...       ...
# 200   nigeria      osun       3         1
# 201   nigeria      osun       3        11
# 202   nigeria      osun       3         5
# 203   nigeria      osun       3         6
# 204  zanzibar  uwandani      na        na
#
# [205 rows x 8 columns]

# %%
info_df["wgs_id"].to_csv("samples.list", sep=",", header=False, index=False)

# %%
# %%bash
#
# bash /master/nplatt/sch_hae_its-nigeria/code/its-12-mitochondria-assembly.sh

# %%
# %%bash
#
# cd /master/nplatt/sch_hae_its-nigeria/results/mito_assembly
#
# mkdir -p /master/nplatt/sch_hae_its-nigeria/results/mito_assembly/ragtag/
#
# # Path to the CSV file
# CSV_FILE="/master/nplatt/sch_hae_its-nigeria/results/mito_read_count/mito_confidence.csv"
#
# # Loop through each line of the CSV file
# while IFS= read -r LINE; do
#     # Extract the first and last fields using awk
#     SAMPLE_ID=$(echo "$LINE" | awk -F',' '{print $1}')
#     REFERENCE=$(echo "$LINE" | awk -F',' '{print $2}')
#
#     OUT_DIR="/master/nplatt/sch_hae_its-nigeria/results/mito_assembly/ragtag/${SAMPLE_ID}"
#     LOG="$OUT_DIR/${SAMPLE_ID}.ragtag.log"
#     SH_SCRIPT="$OUT_DIR/${SAMPLE_ID}.ragtag.sh"
#
#     mkdir -p $OUT_DIR
#     REF_FAS="/master/nplatt/sch_hae_its-nigeria/results/mito_assembly/references/${REFERENCE}.fas"
#
#     # Use ls and select the last file in the list
#     INITIAL_ASSEMBLY=$(ls /master/nplatt/sch_hae_its-nigeria/results/mito_assembly/get_organelle/${SAMPLE_ID}/animal_mt.K85.scaffolds.graph1.1.path_sequence.fasta 2>/dev/null | tail -n 1)
#
#     # Check which assembly file to use
#     if [[ -n "$INITIAL_ASSEMBLY" ]]; then
#         QUERY="$INITIAL_ASSEMBLY"
#     else
#         echo "$SAMPLE_ID missing $INITIAL_ASSEMBLY" >>missing_assemblies.txt
#     fi
#
#     # Make script
#     CMD="conda run -n ragtag --live-stream ragtag.py scaffold -w -t 12 --remove-small -f 500 -u -o $OUT_DIR $REF_FAS $QUERY >$LOG 2>&1"
#     # Write to the script
#     {
#         echo '#!/bin/bash'
#         echo ""
#         echo "$CMD"
#     } > "$SH_SCRIPT"
#     chmod +x $SH_SCRIPT
#
#     echo $SAMPLE_ID
#     bash $SH_SCRIPT
#
# done < <(tail -n +2 "$CSV_FILE")
# Out:
# c_Sh_NG_od_4_5
# c_Sh_NG_bo_6_1
# c_Sh_NG_ed_2_1
# c_Sh_NG_kb_2_3
# c_Sh_NG_kb_2_6
# c_Sh_NG_kw_2_3
# c_Sh_NG_kw_2_7
# Sh_NG_kn_10_1
# Sh_NG_od_5_4
# Sh_NG_od_6_2
# Sh_NG_od_8_3
# Sb_NG_au_2.2
# Sb_NG_ak_2.1
# Sb_NG_au_1.2
# Sb_NG_au_2.11
# Sb_NG_au_2.12
# Sb_NG_au_2.13
# Sb_NG_au_2.14
# Sb_NG_au_2.16
# Sb_NG_au_2.17
# Sb_NG_au_2.3
# Sb_NG_au_2.4
# Sb_NG_au_2.5
# Sb_NG_au_2.6
# Sb_NG_au_2.9
# Sb_NG_be_1.1
# Sb_NG_be_1.10
# Sb_NG_be_1.11
# Sb_NG_be_1.12
# Sb_NG_be_1.3
# Sb_NG_be_1.5
# Sb_NG_be_1.6
# Sb_NG_be_1.9
# Sb_NG_be_2.1
# Sb_NG_be_3.1
# Sb_NG_en_1.1
# SRR11907395
# SRR11907458
# Sb_NG_au_2.10
# Sb_NG_au_2.7
# c_Sh_NG_kn_4_7
# c_Sh_NG_ed_2_3
# c_Sh_NG_eb_2_3
# c_Sh_NG_kn_4_1
# c_Sh_NG_bo_3_1
# c_Sh_NG_bo_3_2
# c_Sh_NG_bo_5_2
# c_Sh_NG_bo_6_2
# c_Sh_NG_bo_7_3
# c_Sh_NG_eb_6_2
# c_Sh_NG_ed_1_1
# c_Sh_NG_ed_2_2
# c_Sh_NG_ed_3_1
# c_Sh_NG_ed_7_1
# c_Sh_NG_kb_2_1
# c_Sh_NG_kb_2_2
# c_Sh_NG_kb_2_9
# c_Sh_NG_kn_11_3
# c_Sh_NG_kn_14_2
# c_Sh_NG_kn_3_2
# c_Sh_NG_ks_1_2
# c_Sh_NG_ks_1_3
# c_Sh_NG_ks_1_7
# c_Sh_NG_kw_1_10
# c_Sh_NG_kw_1_8
# c_Sh_NG_kw_2_2
# c_Sh_NG_kw_2_5
# c_Sh_NG_kw_2_8
# c_Sh_NG_od_10_2
# c_Sh_NG_od_4_4
# c_Sh_NG_od_6_3
# c_Sh_NG_od_9_1
# c_Sh_NG_od_9_2
# c_Sh_NG_os_1_4
# Sh_NG_bo_5_3
# Sh_NG_ed_1_2
# Sh_NG_ed_1_3
# Sh_NG_ed_3_2
# Sh_NG_ed_3_3
# Sh_NG_kn_11_1
# Sh_NG_kn_11_2
# Sh_NG_kw_1_7
# Sh_NG_kw_1_9
# Sh_NG_kw_2_6
# Sh_NG_od_8_1
# Sh_NG_od_9_3
# SRR11907426
# SRR11907524
# SRR11907410
# c_Sh_NG_kb_2_10
# c_Sh_NG_kw_1_4
# c_Sh_NG_os_3_3
# Sh_NG_os_3_1
# SRR11907435
# SRR11907484
# SRR11907431
# c_Sh_NG_bo_7_1
# c_Sh_NG_kb_1_5
# c_Sh_NG_od_4_1
# c_Sh_NG_od_2_3
# c_Sh_NG_od_1_2
# SRR13579880
# SRR7743801
# SRR7743802
# ERR119612
# ERR119613
# ERR310940
# ERR103051
# ERR3012909
# ERR3012900
# ERR3012901
# ERR3012903
# ERR3012904
# ERR3012905
# ERR5919554
# ERR5919558
# ERR5919560
# ERR5908628
# ERR3012902
# ERR5919555
# ERR5919556
# ERR5919559
# ERR5919562
# ERR5919564
# ERR5919567
# ERR5919543
# SRR13579879
# c_Sh_NG_ks_1_9
# c_Sh_NG_kw_2_4
# Sh_NG_od_8_2
# c_Sh_NG_od_13_3
# c_Sh_NG_os_2_2
# c_Sh_NG_os_3_11
# c_Sh_NG_od_3_2
# c_Sh_NG_ed_6_3
# c_Sh_NG_kb_1_2
# c_Sh_NG_eb_6_1
# c_Sh_NG_eb_6_3
# c_Sh_NG_ed_4_1
# c_Sh_NG_kb_2_8
# c_Sh_NG_kn_1_1
# c_Sh_NG_kn_1_6
# c_Sh_NG_kn_13_1
# c_Sh_NG_kn_15_1
# c_Sh_NG_kn_2_4
# c_Sh_NG_kn_3_1
# c_Sh_NG_kn_4_5
# c_Sh_NG_kn_4_6
# c_Sh_NG_kn_5_2
# c_Sh_NG_ks_1_6
# c_Sh_NG_kw_1_1
# c_Sh_NG_od_4_3
# c_Sh_NG_ed_5_2
# c_Sh_NG_ed_6_1
# c_Sh_NG_ed_7_3
# c_Sh_NG_kb_2_7
# c_Sh_NG_kn_10_2
# c_Sh_NG_ks_1_11
# c_Sh_NG_kw_2_1
# c_Sh_NG_ed_5_4
# c_Sh_NG_ks_2_1
# c_Sh_NG_bo_7_2
# c_Sh_NG_eb_5_1
# c_Sh_NG_kn_4_3
# c_Sh_NG_ks_1_4
# c_Sh_NG_ks_3_1
# c_Sh_NG_od_1_1
# c_Sh_NG_bo_5_4
# c_Sh_NG_eb_4_3
# c_Sh_NG_ks_1_10
# c_Sh_NG_ks_1_5
# Sh_NG_kn_14_1
# Sh_NG_kw_1_5
# c_Sh_NG_bo_5_1
# c_Sh_NG_eb_2_2
# c_Sh_NG_bo_4_1
# c_Sh_NG_eb_1_3
# c_Sh_NG_kn_12_1
# c_Sh_NG_kn_2_2
# c_Sh_NG_kn_7_1
# c_Sh_NG_bo_1_3
# c_Sh_NG_bo_5_5
# c_Sh_NG_kn_8_1
# c_Sh_NG_ed_4_2
# c_Sh_NG_ed_5_3
# c_Sh_NG_ed_6_2
# c_Sh_NG_od_11_1
# c_Sh_NG_os_1_2
# c_Sh_NG_od_12_3
# c_Sh_NG_od_12_1
# c_Sh_NG_od_10_1
# c_Sh_NG_os_3_5
# c_Sh_NG_os_3_6
# Sb_NG_ak_1.1
# Sb_NG_ak_2.2
# Sb_NG_ak_2.3
# Sb_NG_ak_3.1
# Sb_NG_au_1.1
# Sb_NG_au_2.1
# Sb_NG_au_2.15
# Sb_NG_au_2.8
# Sb_NG_be_1.4
# Sb_NG_be_3.2
# SRR11907394
# SRR11907383

# %%
# Base directory containing assemblies
base_dir = "/master/nplatt/sch_hae_its-nigeria/results/mito_assembly/ragtag"

# Output files
output_fasta = "mito_assemblies.fasta"
output_stats = "scaffold_counts.csv"
missing_files_log = "missing.files"
small_scaffolds_log = "small_scaffold.files"

# Open the output files
with open(output_fasta, "w") as fasta_out, \
     open(output_stats, "w") as stats_out, \
     open(missing_files_log, "w") as missing_out, \
     open(small_scaffolds_log, "w") as small_out:

    # Write the header for the stats file
    stats_out.write("sample_id,scaffold_count\n")
    
    # Iterate through each subdirectory in the assemblies directory
    for sample_id in os.listdir(base_dir):
        sample_path = os.path.join(base_dir, sample_id, "ragtag.scaffold.fasta")
        
        # Check if the fasta file exists
        if not os.path.isfile(sample_path):
            missing_out.write(f"{sample_path}\n")  # Log missing files
            #print(f"Warning: {sample_path} is missing. Logging to {missing_files_log}.")
            continue
        
        # Parse the fasta file
        longest_seq = None
        scaffold_count = 0
        for record in SeqIO.parse(sample_path, "fasta"):
            scaffold_count += 1
            if longest_seq is None or len(record.seq) > len(longest_seq.seq):
                longest_seq = record
        
        # If no sequences are found, skip this sample
        if scaffold_count == 0:
            print(f"Warning: No sequences found in {sample_path}. Skipping...")
            continue
        
        # Check if the longest sequence is smaller than 5kb
        if len(longest_seq.seq) < 5000:
            small_out.write(f"{sample_path}\n")  # Log small scaffold files
            print(f"Warning: Longest sequence in {sample_path} is smaller than 5kb. Logging to {small_scaffolds_log}.")

        # Modify the header of the longest sequence
        longest_seq.id = f"{sample_id}"
        longest_seq.description = ""  # Clear the description to avoid duplication
        
        # Write the longest sequence to the output fasta file
        SeqIO.write(longest_seq, fasta_out, "fasta")
        
        # Write the sample ID and scaffold count to the stats file
        stats_out.write(f"{sample_id},{scaffold_count}\n")
        
        print(f"Processed {sample_id}: {scaffold_count} scaffolds, longest sequence written to {output_fasta}")

print(f"Processing complete. Results written to {output_fasta}, {output_stats}, {missing_files_log}, and {small_scaffolds_log}.")
# Out:
# Processed c_Sh_NG_kn_4_5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR3012901: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907524: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919560: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_od_8_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.8: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_kw_1_9: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907394: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_7_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_kn_10_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_4_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_6_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_1_5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_3_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_10_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR13579879: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_5_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.17: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_6_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_os_3_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_12_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR119613: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907431: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919556: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919555: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_1_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR7743801: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_2_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR3012909: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_2_5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_4_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_1_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907435: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_1.2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_4_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_2_6: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919562: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_od_5_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5908628: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.12: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_ak_1.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_6: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_9_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_11_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919554: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_12_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.9: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_11_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.12: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_2_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR3012905: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_2_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_4_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907410: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_1_8: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.10: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_od_8_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_os_3_6: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_1_10: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_ak_2.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_os_1_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919543: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_kw_2_6: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_2_9: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_1.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_2_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_1_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_1_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_2_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_6_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919558: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_5_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_2_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_2_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_2_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_15_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_2_8: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_13_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_1_6: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_3_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_14_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_10: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907395: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.13: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.15: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_2_7: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_7_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919567: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_os_3_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR13579880: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907426: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_os_3_11: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_7: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_1_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_2_7: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_4_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_4_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.6: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_ak_3.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_4_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_3_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.11: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_eb_2_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.7: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR3012902: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_10_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_6_1: 2 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.11: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_3.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_od_6_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_4_6: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_4_7: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR103051: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_os_2_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_3_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_9: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_3_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_2_8: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_5_2: 2 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.9: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_1_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_12_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR3012900: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_kn_14_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_5_5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_1.10: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_4_5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_2_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_13_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_1_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR3012904: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_en_1.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_3.2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_ed_1_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_11: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_2_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_3_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_ed_3_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR7743802: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_eb_6_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_ed_1_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_eb_1_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_2_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_8_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_eb_5_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ks_1_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_9_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907484: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_7_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919564: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_od_9_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_2_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_7_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.6: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.14: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_od_10_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_ak_2.2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_1_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_au_2.16: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_eb_2_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_kw_1_7: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_bo_5_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_5_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR5919559: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_5_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_6_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_5_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_eb_4_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_be_2.1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907458: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_6_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR3012903: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_od_8_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_os_3_5: 2 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_eb_6_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_3_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_7_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR119612: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_2_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_bo_7_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kb_2_10: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_eb_6_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed SRR11907383: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed ERR310940: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sb_NG_ak_2.3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_kn_11_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kw_2_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_os_1_4: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_ed_3_3: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_kn_5_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_kw_1_5: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed c_Sh_NG_ed_4_1: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processed Sh_NG_kn_11_2: 1 scaffolds, longest sequence written to mito_assemblies.fasta
# Processing complete. Results written to mito_assemblies.fasta, scaffold_counts.csv, missing.files, and small_scaffold.files.
